# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

# %%
df=pd.read_csv('IPL_ball_by_ball_updated.csv')

# %%
df.head()
# Out:
#    match_id  season  start_date                  venue  innings  ball                 batting_team           bowling_team     striker non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   6.8  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White  AB Agarkar             4       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 1    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   2.7  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis    AB Dinda             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 2    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   3.1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis    I Sharma             2       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 3    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   3.2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis    I Sharma             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 4    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   3.3  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer    I Sharma             0       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN

# %%
df.innings.unique()
# Out:
# array([2, 1, 4, 3, 6, 5])

# %%
df=df[(df.innings==1)|(df.innings==2)]

# %%
df.innings.unique()
# Out:
# array([2, 1])

# %%
df.bowling_team.unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings'],
#       dtype=object)

# %%
df[df.bowling_team == 'Mumbai Indians']['bowler'].unique()
# Out:
# array(['DS Kulkarni', 'Harbhajan Singh', 'A Nehra', 'AM Nayar',
#        'ST Jayasuriya', 'SM Pollock', 'MA Khote', 'DJ Bravo',
#        'VS Yeligati', 'SD Chitnis', 'CRD Fernando', 'DJ Thornely',
#        'RR Raje', 'DR Smith', 'A Nel', 'SL Malinga', 'Z Khan',
#        'SR Tendulkar', 'JP Duminy', 'GR Napier', 'C Nanda', 'AM Rahane',
#        'RA Shaikh', 'R McLaren', 'R Sathish', 'AG Murtaza', 'KA Pollard',
#        'AN Ahmed', 'STR Binny', 'JEC Franklin', 'MM Patel', 'RG Sharma',
#        'A Symonds', 'TL Suman', 'RW Price', 'PP Ojha', 'RP Singh',
#        'CJ McKay', 'NLTC Perera', 'RJ Peterson', 'R Shukla', 'JJ Bumrah',
#        'MG Johnson', 'JDP Oram', 'R Dhawan', 'YS Chahal', 'P Suyal',
#        'GJ Maxwell', 'NM Coulter-Nile', 'CJ Anderson', 'P Kumar',
#        'LMP Simmons', 'S Gopal', 'K Santokie', 'M de Lange',
#        'R Vinay Kumar', 'J Suchith', 'MJ McClenaghan', 'HH Pandya',
#        'TG Southee', 'KH Pandya', 'N Rana', 'KV Sharma', 'M Markande',
#        'Mustafizur Rahman', 'PJ Sangwan', 'BCJ Cutting', 'A Dananjaya',
#        'Rasikh Salam', 'RD Chahar', 'JP Behrendorff', 'AS Joseph',
#        'J Yadav', 'AS Roy', 'BB Sran', 'TA Boult', 'JL Pattinson',
#        'M Jansen', 'AF Milne', 'JDS Neesham', 'PP Chawla'], dtype=object)

# %%
##analysis of bumrah and ab de villers
##analysis of bumrah and ms dhoni
##figuring out who is the best amongst the two

# %%
df[df.batting_team=='Royal Challengers Bangalore']['striker'].unique()
# Out:
# array(['MV Boucher', 'W Jaffer', 'JH Kallis', 'CL White', 'V Kohli',
#        'R Dravid', 'P Kumar', 'Z Khan', 'SB Joshi', 'AA Noffke',
#        'B Akhil', 'LRPL Taylor', 'S Chanderpaul', 'R Vinay Kumar',
#        'B Chipli', 'DW Steyn', 'Misbah-ul-Haq', 'DT Patil', 'A Kumble',
#        'J Arunkumar', 'Abdur Razzak', 'SP Goswami', 'KP Pietersen',
#        'RV Uthappa', 'JD Ryder', 'R Bishnoi', 'KV Sharma', 'Pankaj Singh',
#        'MK Pandey', 'RE van der Merwe', 'KP Appanna', 'D du Preez',
#        'EJG Morgan', 'A Mithun', 'S Sriram', 'AUK Pathan',
#        'AB de Villiers', 'TM Dilshan', 'SS Tiwary', 'MA Agarwal',
#        'DL Vettori', 'CA Pujara', 'JJ van der Wath', 'R Ninan',
#        'S Aravind', 'CH Gayle', 'J Syed Mohammad', 'M Kaif',
#        'LA Pomersbach', 'KB Arun Karthik', 'CK Langeveldt', 'AB McDonald',
#        'HV Patel', 'RR Bhatkal', 'M Muralitharan', 'P Parameswaran',
#        'KK Nair', 'DT Christian', 'MC Henriques', 'M Kartik',
#        'JD Unadkat', 'R Rampaul', 'KL Rahul', 'A Mukund', 'Yuvraj Singh',
#        'PA Patel', 'NJ Maddinson', 'JA Morkel', 'YV Takawale', 'MA Starc',
#        'AB Dinda', 'S Rana', 'VR Aaron', 'RR Rossouw', 'YS Chahal',
#        'VH Zol', 'AN Ahmed', 'KD Karthik', 'Mandeep Singh', 'DJG Sammy',
#        'SA Abbott', 'D Wiese', 'Iqbal Abdulla', 'MS Bisla', 'SN Khan',
#        'KM Jadhav', 'SR Watson', 'TM Head', 'KW Richardson', 'STR Binny',
#        'Sachin Baby', 'Parvez Rasool', 'CJ Jordan', 'TS Mills',
#        'A Choudhary', 'P Negi', 'Vishnu Vinod', 'AF Milne', 'S Badree',
#        'CR Woakes', 'BB McCullum', 'Q de Kock', 'Washington Sundar',
#        'CJ Anderson', 'UT Yadav', 'Mohammed Siraj', 'M Vohra',
#        'C de Grandhomme', 'TG Southee', 'M Ashwin', 'MM Ali',
#        'SO Hetmyer', 'S Dube', 'NA Saini', 'P Ray Barman', 'MP Stoinis',
#        'AD Nath', 'Gurkeerat Singh', 'H Klaasen', 'D Padikkal',
#        'JR Philippe', 'AJ Finch', 'I Udana', 'CH Morris', 'Shahbaz Ahmed',
#        'GJ Maxwell', 'RM Patidar', 'KA Jamieson', 'DR Sams', 'KS Bharat',
#        'PWH de Silva', 'TH David', 'GHS Garton'], dtype=object)

# %%
req_df = df[(df.striker == 'AB de Villiers') & (df.bowler == 'JJ Bumrah')]

# %%
req_df.head()
# Out:
#        match_id  season  start_date                                venue  innings  ball                 batting_team    bowling_team         striker non_striker     bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 95691    729287    2014  19-04-2014  Dubai International Cricket Stadium        2   6.1  Royal Challengers Bangalore  Mumbai Indians  AB de Villiers    PA Patel  JJ Bumrah             2       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 95692    729287    2014  19-04-2014  Dubai International Cricket Stadium        2   6.2  Royal Challengers Bangalore  Mumbai Indians  AB de Villiers    PA Patel  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 95695    729287    2014  19-04-2014  Dubai International Cricket Stadium        2   6.4  Royal Challengers Bangalore  Mumbai Indians  AB de Villiers    PA Patel  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 95928    729287    2014  19-04-2014  Dubai International Cricket Stadium        2  11.6  Royal Challengers Bangalore  Mumbai Indians  AB de Villiers    PA Patel  JJ Bumrah             0       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 95942    729287    2014  19-04-2014  Dubai International Cricket Stadium        2  11.1  Royal Challengers Bangalore  Mumbai Indians  AB de Villiers    PA Patel  JJ Bumrah             6       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN

# %%
sum(req_df.runs_off_bat) ##runs scored
# Out:
# 125

# %%
len(req_df) ##balls faced
# Out:
# 86

# %%
len(req_df[req_df.player_dismissed == 'AB de Villers']) ##outs
# Out:
# 0

# %%
100* sum(req_df.runs_off_bat)/len(req_df)
# Out:
# 145.34883720930233

# %%
df.head(1)
# Out:
#    match_id  season  start_date                  venue  innings  ball                 batting_team           bowling_team     striker non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0    335982    2008  18-04-2008  M Chinnaswamy Stadium        2   6.8  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White  AB Agarkar             4       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN

# %%
bumrah_df=df[df.bowler == 'JJ Bumrah']

# %%
bumrah_df.head()
# Out:
#        match_id  season  start_date                  venue  innings  ball                 batting_team    bowling_team          striker      non_striker     bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 76627    597999    2013  04-04-2013  M Chinnaswamy Stadium        1  12.6  Royal Challengers Bangalore  Mumbai Indians         CH Gayle  KB Arun Karthik  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 76628    597999    2013  04-04-2013  M Chinnaswamy Stadium        1  12.5  Royal Challengers Bangalore  Mumbai Indians  KB Arun Karthik         CH Gayle  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 76629    597999    2013  04-04-2013  M Chinnaswamy Stadium        1  12.4  Royal Challengers Bangalore  Mumbai Indians          KK Nair         CH Gayle  JJ Bumrah             0       0    NaN      NaN   NaN      NaN      NaN         lbw          KK Nair                NaN                     NaN
# 76630    597999    2013  04-04-2013  M Chinnaswamy Stadium        1  12.3  Royal Challengers Bangalore  Mumbai Indians         CH Gayle          KK Nair  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 76631    597999    2013  04-04-2013  M Chinnaswamy Stadium        1  12.2  Royal Challengers Bangalore  Mumbai Indians         CH Gayle          KK Nair  JJ Bumrah             0       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN

# %%
##runs scored by this batsman
bdf1=pd.DataFrame(bumrah_df.groupby('striker')['runs_off_bat'].sum()).reset_index()

# %%
bdf1.head()
# Out:
#           striker  runs_off_bat
# 0        A Mishra             1
# 1  AB de Villiers           125
# 2         AD Nath             4
# 3      AD Russell            51
# 4        AJ Finch            24

# %%
bdf2=pd.DataFrame(bumrah_df.groupby('striker')['ball'].count()).reset_index()

# %%
bdf2.head()
# Out:
#           striker  ball
# 0        A Mishra     5
# 1  AB de Villiers    86
# 2         AD Nath     4
# 3      AD Russell    41
# 4        AJ Finch    29

# %%
bdf3=bdf1.merge(bdf2,on='striker',how='left')

# %%
bdf3.head()
# Out:
#           striker  runs_off_bat  ball
# 0        A Mishra             1     5
# 1  AB de Villiers           125    86
# 2         AD Nath             4     4
# 3      AD Russell            51    41
# 4        AJ Finch            24    29

# %%
bdf3['strike_rate']= 100*bdf3['runs_off_bat']/bdf3['ball']

# %%
bdf3.head()
# Out:
#           striker  runs_off_bat  ball  strike_rate
# 0        A Mishra             1     5    20.000000
# 1  AB de Villiers           125    86   145.348837
# 2         AD Nath             4     4   100.000000
# 3      AD Russell            51    41   124.390244
# 4        AJ Finch            24    29    82.758621

# %%
##creating a minimum criteria of 30 balls
bdf3=bdf3[bdf3.ball>=30]
bdf3.head()
# Out:
#            striker  runs_off_bat  ball  strike_rate
# 1   AB de Villiers           125    86   145.348837
# 3       AD Russell            51    41   124.390244
# 8        AM Rahane            43    35   122.857143
# 9         AR Patel            21    32    65.625000
# 12       AT Rayudu            48    34   141.176471

# %%
abd_df = df[df.striker =='AB de Villiers']

# %%
abd_df.head()
# Out:
#       match_id  season  start_date                            venue  innings  ball      batting_team         bowling_team         striker non_striker          bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 4575    336001    2008  02-05-2008  MA Chidambaram Stadium, Chepauk        2  14.6  Delhi Daredevils  Chennai Super Kings  AB de Villiers    S Dhawan         MS Gony             2       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 4578    336001    2008  02-05-2008  MA Chidambaram Stadium, Chepauk        2  15.3  Delhi Daredevils  Chennai Super Kings  AB de Villiers    S Dhawan         M Ntini             2       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 4579    336001    2008  02-05-2008  MA Chidambaram Stadium, Chepauk        2  15.4  Delhi Daredevils  Chennai Super Kings  AB de Villiers    S Dhawan         M Ntini             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 4581    336001    2008  02-05-2008  MA Chidambaram Stadium, Chepauk        2  15.6  Delhi Daredevils  Chennai Super Kings  AB de Villiers    S Dhawan         M Ntini             0       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 4587    336001    2008  02-05-2008  MA Chidambaram Stadium, Chepauk        2  16.6  Delhi Daredevils  Chennai Super Kings  AB de Villiers    S Dhawan  M Muralitharan             4       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN

# %%
adf1=pd.DataFrame(abd_df.groupby('bowler')['runs_off_bat'].sum()).reset_index()

# %%
adf1.head()
# Out:
#            bowler  runs_off_bat
# 0  A Ashish Reddy            46
# 1      A Chandila            26
# 2      A Flintoff            34
# 3        A Kumble            39
# 4        A Mishra            40

# %%
adf2=pd.DataFrame(abd_df.groupby('bowler')['ball'].count()).reset_index()

# %%
adf2.head()
# Out:
#            bowler  ball
# 0  A Ashish Reddy    18
# 1      A Chandila    11
# 2      A Flintoff    12
# 3        A Kumble    41
# 4        A Mishra    37

# %%
adf3=adf1.merge(adf2,on='bowler',how='left')

# %%
adf3.head()
# Out:
#            bowler  runs_off_bat  ball
# 0  A Ashish Reddy            46    18
# 1      A Chandila            26    11
# 2      A Flintoff            34    12
# 3        A Kumble            39    41
# 4        A Mishra            40    37

# %%
adf3['strike_rate']= 100*adf3['runs_off_bat']/adf3['ball']
adf3.head()
# Out:
#            bowler  runs_off_bat  ball  strike_rate
# 0  A Ashish Reddy            46    18   255.555556
# 1      A Chandila            26    11   236.363636
# 2      A Flintoff            34    12   283.333333
# 3        A Kumble            39    41    95.121951
# 4        A Mishra            40    37   108.108108

# %%
##creating a minimum criteria of 30 balls
adf3=adf3[adf3.ball>=30]
adf3.head()
# Out:
#         bowler  runs_off_bat  ball  strike_rate
# 3     A Kumble            39    41    95.121951
# 4     A Mishra            40    37   108.108108
# 16  AD Russell            87    39   223.076923
# 20    AR Patel            71    70   101.428571
# 32     B Kumar            68    43   158.139535

# %%
bdf3.reset_index(inplace=True, drop=True)
adf3.reset_index(inplace=True, drop=True)

# %%
bdf3.head()
# Out:
#           striker  runs_off_bat  ball  strike_rate
# 0  AB de Villiers           125    86   145.348837
# 1      AD Russell            51    41   124.390244
# 2       AM Rahane            43    35   122.857143
# 3        AR Patel            21    32    65.625000
# 4       AT Rayudu            48    34   141.176471

# %%
plt.figure(figsize = (16, 8))
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)
for i in range(len(bdf3)):
    if bdf3['striker'][i] == 'V Kohli':
        plt.text(bdf3['strike_rate'][i] - 7, bdf3['runs_off_bat'][i] - 1, bdf3['striker'][i] )
    else:
        plt.text(bdf3['strike_rate'][i] + 1, bdf3['runs_off_bat'][i] - 1, bdf3['striker'][i] )
plt.axvline(120, ls = '--', color = 'red')
plt.axhline(60, ls = '--', color = 'red')
plt.title('Batsman against Bumrah in IPL who faced min 30 balls', fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)
for i in range(len(bdf3)):
    if bdf3.striker[i] == 'V Kohli':
        plt.text(bdf3.strike_rate[i] - 7, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])
    elif bdf3.striker[i] == 'AB de Villiers':
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i], color = 'maroon')
    elif (bdf3.striker[i] == 'S Dhawan') | (bdf3.striker[i] == 'KL Rahul') | (bdf3.striker[i] == 'JP Duminy'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])
plt.axvline(120, ls = '--', color = 'red')
plt.axhline(60, ls = '--', color = 'red')
plt.title("Best Batman against Bumrah who faced a minimum of 30 balls", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.rcParams['axes.facecolor']='#fff7fb'
plt.scatter(adf3.strike_rate,adf3.runs_off_bat)
for i in range(len(adf3)):
  if adf3.bowler[i] == 'JJ Bumrah':
    plt.text(adf3.strike_rate[i]+2,adf3.runs_off_bat[i]-1,adf3.bowler[i],color='maroon')
  elif (adf3.bowler[i]=='RA Jadeja')|(adf3.bowler[i]=='SL Malinga')|(adf3.bowler[i]=='Sandeep Sharma')|(adf3.bowler[i]=='Harbhajan Singh'):
    plt.text(adf3.strike_rate[i]+2,adf3.runs_off_bat[i]-1,adf3.bowler[i])
  elif (adf3.bowler[i]=='HH Pandya'):
    plt.text(adf3.strike_rate[i],adf3.runs_off_bat[i]+2,adf3.bowler[i])
  elif (adf3.bowler[i]=='AD Russell'):
    plt.text(adf3.strike_rate[i]-3,adf3.runs_off_bat[i]-3,adf3.bowler[i])

plt.axvline(120,ls='--',color='red')
plt.axhline(60,ls='--',color='red')
plt.title('ABC Favourite bowlers',fontsize=20)
plt.xlabel('Strike Rate')
plt.ylabel('Runs Scored')
plt.savefig('Chart_ABD_vs_Bumrah_part2.jpg')
plt.show()

# %%
##Comparison of MS Dhoni vs AB de villers when they face jasprit bumrah
df[df.batting_team == 'Chennai Super Kings']['striker'].unique()
# Out:
# array(['MEK Hussey', 'JDP Oram', 'SK Raina', 'S Badrinath', 'ML Hayden',
#        'PA Patel', 'MS Dhoni', 'JA Morkel', 'S Vidyut', 'SP Fleming',
#        'MS Gony', 'Joginder Sharma', 'M Muralitharan', 'M Ntini',
#        'S Anirudha', 'CK Kapugedera', 'L Balaji', 'A Mukund',
#        'T Thushara', 'A Flintoff', 'SB Jakati', 'M Vijay', 'GJ Bailey',
#        'R Ashwin', 'S Tyagi', 'JM Kemp', 'KB Arun Karthik',
#        'DE Bollinger', 'SB Styris', 'S Randiv', 'WP Saha', 'DJ Bravo',
#        'F du Plessis', 'RA Jadeja', 'KMDN Kulasekara', 'B Laughlin',
#        'AS Rajpoot', 'CH Morris', 'MM Sharma', 'DR Smith', 'BB McCullum',
#        'M Manhas', 'DJ Hussey', 'A Nehra', 'P Negi', 'RG More',
#        'KM Jadhav', 'AT Rayudu', 'SR Watson', 'MA Wood', 'Imran Tahir',
#        'Harbhajan Singh', 'DL Chahar', 'SW Billings', 'DR Shorey',
#        'SN Thakur', 'MJ Santner', 'SM Curran', 'RD Gaikwad',
#        'N Jagadeesan', 'MM Ali', 'RV Uthappa'], dtype=object)

# %%
req_df = df[(df.striker == 'MS Dhoni') & (df.bowler == 'JJ Bumrah')]

# %%
req_df.head()
# Out:
#         match_id  season  start_date                                    venue  innings  ball             batting_team    bowling_team   striker  non_striker     bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 102014    733995    2014  10-05-2014                         Wankhede Stadium        2  17.4      Chennai Super Kings  Mumbai Indians  MS Dhoni    RA Jadeja  JJ Bumrah             2       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 102017    733995    2014  10-05-2014                         Wankhede Stadium        2  17.1      Chennai Super Kings  Mumbai Indians  MS Dhoni    RA Jadeja  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 102020    733995    2014  10-05-2014                         Wankhede Stadium        2  17.5      Chennai Super Kings  Mumbai Indians  MS Dhoni    RA Jadeja  JJ Bumrah             0       1    1.0      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 102021    733995    2014  10-05-2014                         Wankhede Stadium        2  17.6      Chennai Super Kings  Mumbai Indians  MS Dhoni    RA Jadeja  JJ Bumrah             1       0    NaN      NaN   NaN      NaN      NaN         NaN              NaN                NaN                     NaN
# 128906    980957    2016  01-05-2016  Maharashtra Cricket Association Stadium        1  19.2  Rising Pune Supergiants  Mumbai Indians  MS Dhoni  NLTC Perera  JJ Bumrah             0       0    NaN      NaN   NaN      NaN      NaN      caught         MS Dhoni                NaN                     NaN

# %%
sum(req_df.runs_off_bat) #runs scored
# Out:
# 56

# %%
len(req_df) #balls faced
# Out:
# 58

# %%
len(req_df[req_df.player_dismissed == 'MS Dhoni']) ##outs
# Out:
# 3

# %%
# strike rate
100*sum(req_df.runs_off_bat)/len(req_df)
# Out:
# 96.55172413793103

# %%
dhoni_df = df[df.striker =='MS Dhoni']

# %%
# runs scored by this batsman
dhoni1 = pd.DataFrame(dhoni_df.groupby('bowler')['runs_off_bat'].sum()).reset_index()

# %%
dhoni1.head()
# Out:
#            bowler  runs_off_bat
# 0  A Ashish Reddy            27
# 1        A Kumble            23
# 2        A Mishra            50
# 3        A Mithun            34
# 4         A Nehra            76

# %%
dhoni2 = pd.DataFrame(dhoni_df.groupby('bowler')['ball'].count()).reset_index()

# %%
dhoni2.head()
# Out:
#            bowler  ball
# 0  A Ashish Reddy    16
# 1        A Kumble    27
# 2        A Mishra    41
# 3        A Mithun    15
# 4         A Nehra    40

# %%
dhoni3 = dhoni1.merge(dhoni2, on = 'bowler', how = 'left')
dhoni3['strike_rate'] = 100*dhoni3['runs_off_bat']/dhoni3['ball']
dhoni3 = dhoni3[dhoni3.ball >= 30]
dhoni3.head()
# Out:
#         bowler  runs_off_bat  ball  strike_rate
# 2     A Mishra            50    41   121.951220
# 4      A Nehra            76    40   190.000000
# 8   AB Agarkar            46    32   143.750000
# 19    AR Patel            75    65   115.384615
# 28     B Kumar            93    58   160.344828

# %%
bdf3.reset_index(inplace = True, drop = True)
dhoni3.reset_index(inplace = True, drop = True)

# %%
plt.figure(figsize = (6,6))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)
for i in range(len(bdf3)):
    if bdf3.striker[i] == 'V Kohli':
        plt.text(bdf3.strike_rate[i] , bdf3.runs_off_bat[i] , bdf3.striker[i])
    elif bdf3.striker[i] == 'MS Dhoni':
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i], color = 'maroon')
    elif (bdf3.striker[i] == 'S Dhawan') | (bdf3.striker[i] == 'KL Rahul') | (bdf3.striker[i] == 'JP Duminy'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])

plt.axvline(120, ls = '--', color = 'red')
plt.axhline(60, ls = '--', color = 'red')
plt.title("Best Batman against Bumrah", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart Dhoni vs Bumrah.jpg')
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(dhoni3.strike_rate, dhoni3.runs_off_bat)
for i in range(len(dhoni3)):
    if dhoni3.bowler[i] == 'JJ Bumrah':
        plt.text(dhoni3.strike_rate[i] + 2, dhoni3.runs_off_bat[i] - 1, dhoni3.bowler[i], color = 'maroon')
    elif (dhoni3.bowler[i] == 'RA Jadeja') | (dhoni3.bowler[i] == 'SL Malinga') | (dhoni3.bowler[i] == 'Sandeep Sharma') | (dhoni3.bowler[i] == 'Harbhajan Singh'):
        plt.text(dhoni3.strike_rate[i] + 2, dhoni3.runs_off_bat[i] - 1, dhoni3.bowler[i])
    elif (dhoni3.bowler[i] == 'HH Pandya'):
        plt.text(dhoni3.strike_rate[i], dhoni3.runs_off_bat[i] + 2, dhoni3.bowler[i])
    elif (dhoni3.bowler[i] == 'AD Russell'):
        plt.text(dhoni3.strike_rate[i] - 3, dhoni3.runs_off_bat[i] - 3, dhoni3.bowler[i])

plt.axvline(110, ls = '--', color = 'red')
plt.axhline(80, ls = '--', color = 'red')
plt.title("Dhoni's Favorite Bowlers", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart_DHONI_vs_Bumrah_part2.jpg')
plt.show()
